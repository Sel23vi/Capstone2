# %% [raw]
# import pandas as pd
# import json
# import os
# import mysql.connector
# mydb=mysql.connector.connect(
#     host="localhost",
#     user="root",
#     password='xxxxxx',
# )
# pointer=mydb.cursor()
# pointer.execute('use capstone2;')

# %% [raw]
# def PhonePe():
#     import pandas as pd
#     import json
#     import os
#     path = r'Desktop/Project/Phonepe db/data_new/aggregated/transaction/country/india/state'
#     Agg_state_list=os.listdir(path)
#     clm={'State':[], 'Year':[],'Quater':[],'Transacion_type':[], 'Transacion_count':[], 'Transacion_amount':[]}
#     for i in Agg_state_list:
#         p_i=path+'/'+i
#         Agg_yr_list=os.listdir(p_i)
#         for j in Agg_yr_list:
#             p_j=p_i+'/'+ j
#             Agg_yr_jlist=os.listdir(p_j)
#
#     return len(Agg_yr_list), len(Agg_yr_jlist)
#
#
# def Agg_Userf(m):
#     path_new = r'Desktop/Project/Phonepe db/data_new/aggregated/transaction/country/india/state'
#     Agg_state_list_new=os.listdir(path_new)
#     clm={'State':[], 'Year':[],'Quater':[],'UserByDevice_Brand':[], 'UserByDevice_Count':[], 'UserByDevice_Percentage':[]}
#     for i in Agg_state_list_new:
#         p_i=path+'/'+i
#         Agg_yr_list_new=os.listdir(p_i)
#         j = Agg_yr_list_new[-1]
#         p_j=p_i+'/'+ j
#         Agg_yr_jlist_new=os.listdir(p_j)
#         for a in range (-1,-(m+1),-1):
#             k = Agg_yr_jlist_new[a]
#             p_k=p_j+'/'+k
#             Data=open(p_k,'r')
#             D=json.load(Data)
#             if D['data']['usersByDevice']!=None:
#                 for z in D['data']['usersByDevice']:
#                     Brand = z.get('brand',None)
#                     Count = z.get('count',None)
#                     Percentage =z.get('percentage',None)
#                     clm['UserByDevice_Brand'].append(Brand)
#                     clm['UserByDevice_Count'].append(Count)
#                     clm['UserByDevice_Percentage'].append(Percentage)
#                     clm['State'].append(i)
#                     clm['Year'].append(j)
#                     clm['Quater'].append(int(k.strip('.json')))
#             else:
#                 continue
#     Agg_Userf_new=pd.DataFrame(clm)
#
#     my_dict = {'andaman-&-nicobar-islands':'Andaman & Nicobar Islands', 'andhra-pradesh':'Andhra Pradesh', 'arunachal-pradesh':'Arunachal Pradesh',
#                'assam':'Assam', 'bihar':'Bihar', 'chandigarh':'Chandigarh', 'chhattisgarh':'Chhattisgarh', 'dadra-&-nagar-haveli-&-daman-&-diu':'Dadra & Nagar Haveli & Daman & Diu',
#                'delhi':'Delhi', 'goa':'Goa', 'gujarat':'Gujarat', 'haryana':'Haryana', 'himachal-pradesh':'Himachal Pradesh', 'jammu-&-kashmir':'Jammu & Kashmir',
#                'jharkhand':'Jharkhand', 'karnataka':'Karnataka', 'kerala':'Kerala', 'ladakh':'Ladakh', 'lakshadweep':'Lakshadweep', 'madhya-pradesh':'Madhya Pradesh',
#                'maharashtra':'Maharashtra', 'manipur':'Manipur', 'meghalaya':'Meghalaya', 'mizoram':'Mizoram', 'nagaland':'Nagaland', 'odisha':'Odisha',
#                'puducherry':'Puducherry', 'punjab':'Punjab', 'rajasthan':'Rajasthan', 'sikkim':'Sikkim', 'tamil-nadu':'Tamil Nadu', 'telangana':'Telengana',
#                'tripura':'Tripura', 'uttar-pradesh':'Uttar Pradesh', 'uttarakhand':'Uttarakhand', 'west-bengal':'West Bengal'}
#
#     Agg_Userf_new['State'] = Agg_Userf_new['State'].map(my_dict)
#     Agg_Userf_new.rename(columns={'Quater':'Quarter'},inplace=True)
#
#     return Agg_Userf_new
#
# def Map_Transf_new(m):
#     path = r'Desktop/Project/Phonepe db/data/map/transaction/hover/country/india/state'
#     Map_state_list_new=os.listdir(path)
#     clm={'State':[], 'Year':[],'Quater':[],'District_Name':[], 'DistrictWise_T.count':[], 'DistrictWise_T.amount':[]}
#     for i in Map_state_list_new:
#         p_i=path+'/'+i
#         Map_yr_list_new_=os.listdir(p_i)
#         j = Map_yr_list_new[-1]
#         p_j=p_i+'/'+ j
#         Map_yr_jlist_new=os.listdir(p_j)
#         for a in range (-1,-(m+1),-1):
#             k = Map_yr_jlist[a]:
#             p_k=p_j+'/'+k
#             Data=open(p_k,'r')
#             D=json.load(Data)
#             for z in D['data']['hoverDataList']:
#                 Dist_Name=z['name']
#                 Dist_count=z['metric'][0]['count']
#                 Dist_amount=z['metric'][0]['amount']
#                 clm['State'].append(i)
#                 clm['Year'].append(j)
#                 clm['Quater'].append(int(k.strip('.json')))
#                 clm['District_Name'].append(Dist_Name)
#                 clm['DistrictWise_T.count'].append(Dist_count)
#                 clm['DistrictWise_T.amount'].append(Dist_amount)
#     Map_Transf_new = pd.DataFrame(clm)
#
#     my_dict = {'andaman-&-nicobar-islands':'Andaman & Nicobar Islands', 'andhra-pradesh':'Andhra Pradesh', 'arunachal-pradesh':'Arunachal Pradesh',
#            'assam':'Assam', 'bihar':'Bihar', 'chandigarh':'Chandigarh', 'chhattisgarh':'Chhattisgarh', 'dadra-&-nagar-haveli-&-daman-&-diu':'Dadra & Nagar Haveli & Daman & Diu',
#            'delhi':'Delhi', 'goa':'Goa', 'gujarat':'Gujarat', 'haryana':'Haryana', 'himachal-pradesh':'Himachal Pradesh', 'jammu-&-kashmir':'Jammu & Kashmir',
#            'jharkhand':'Jharkhand', 'karnataka':'Karnataka', 'kerala':'Kerala', 'ladakh':'Ladakh', 'lakshadweep':'Lakshadweep', 'madhya-pradesh':'Madhya Pradesh',
#            'maharashtra':'Maharashtra', 'manipur':'Manipur', 'meghalaya':'Meghalaya', 'mizoram':'Mizoram', 'nagaland':'Nagaland', 'odisha':'Odisha',
#            'puducherry':'Puducherry', 'punjab':'Punjab', 'rajasthan':'Rajasthan', 'sikkim':'Sikkim', 'tamil-nadu':'Tamil Nadu', 'telangana':'Telengana',
#            'tripura':'Tripura', 'uttar-pradesh':'Uttar Pradesh', 'uttarakhand':'Uttarakhand', 'west-bengal':'West Bengal'}
#
#     Map_Transf_new['State'] = Map_Trans_new['State'].map(my_dict)
#     return Map_Transf_new
#
# def Map_Users(m):
#     path = r'Desktop/Project/Phonepe db/data/map/user/hover/country/india/state'
#     Map_state_list_new=os.listdir(path)
#     clm={'State':[], 'Year':[],'Quater':[],'District_Name':[], 'Registered_Users_Count':[], 'AppOpens':[]}
#     for i in Map_state_list_new:
#         p_i=path+'/'+i
#         Map_yr_list_new=os.listdir(p_i)
#         j = Map_yr_list_new[-1]
#         p_j=p_i+'/'+ j
#         Map_yr_jlist_new=os.listdir(p_j)
#         for a in range (-1,-(m+1),-1):
#             k = Map_yr_jlist_new[a]
#             p_k=p_j+'/'+k
#             Data=open(p_k,'r')
#             D=json.load(Data)
#             for key,value in D['data']['hoverData'].items():
#                 Dist_Name = key
#                 for key,value in D['data']['hoverData'][Dist_Name].items():
#                     if key == 'registeredUsers':
#                         RegUser_count = value
#                     elif key == 'appOpens':
#                         AppOpens = value
#                 clm['State'].append(i)
#                 clm['Year'].append(j)
#                 clm['Quater'].append(int(k.strip('.json')))
#                 clm['District_Name'].append(Dist_Name)
#                 clm['Registered_Users_Count'].append(RegUser_count)
#                 clm['AppOpens'].append(AppOpens)
#     Map_Users_new = pd.DataFrame(clm)
#     my_dict = {'andaman-&-nicobar-islands':'Andaman & Nicobar Islands', 'andhra-pradesh':'Andhra Pradesh', 'arunachal-pradesh':'Arunachal Pradesh',
#                'assam':'Assam', 'bihar':'Bihar', 'chandigarh':'Chandigarh', 'chhattisgarh':'Chhattisgarh', 'dadra-&-nagar-haveli-&-daman-&-diu':'Dadra & Nagar Haveli & Daman & Diu',
#                'delhi':'Delhi', 'goa':'Goa', 'gujarat':'Gujarat', 'haryana':'Haryana', 'himachal-pradesh':'Himachal Pradesh', 'jammu-&-kashmir':'Jammu & Kashmir',
#                'jharkhand':'Jharkhand', 'karnataka':'Karnataka', 'kerala':'Kerala', 'ladakh':'Ladakh', 'lakshadweep':'Lakshadweep', 'madhya-pradesh':'Madhya Pradesh',
#                'maharashtra':'Maharashtra', 'manipur':'Manipur', 'meghalaya':'Meghalaya', 'mizoram':'Mizoram', 'nagaland':'Nagaland', 'odisha':'Odisha',
#                'puducherry':'Puducherry', 'punjab':'Punjab', 'rajasthan':'Rajasthan', 'sikkim':'Sikkim', 'tamil-nadu':'Tamil Nadu', 'telangana':'Telengana',
#                'tripura':'Tripura', 'uttar-pradesh':'Uttar Pradesh', 'uttarakhand':'Uttarakhand', 'west-bengal':'West Bengal'}
#     Map_Users_new['State'] = Map_Users_new['State'].map(my_dict)
#     return Map_Users_new
#
#
# def Top_Trans_Dist(m):
#     path = r'Desktop/Project/Phonepe db/data/top/transaction/country/india/state'
#     Top_state_list_new=os.listdir(path)
#     clm={'State':[], 'Year':[],'Quater':[],'District_Name':[], 'DistrictWise_count':[], 'DistrictWise_amount':[]}
#     for i in Top_state_list_new:
#         p_i=path+'/'+i
#         Top_yr_list_new=os.listdir(p_i)
#         j = Top_yr_list_new[-1]
#         p_j=p_i+'/'+ j
#         Top_yr_jlist_new=os.listdir(p_j)
#         for a in range (-1,-(m+1),-1):
#             k = Top_yr_jlist_new[a]
#             p_k=p_j+'/'+k
#             Data=open(p_k,'r')
#             D=json.load(Data)
#             for z in D['data']['districts']:
#                 Dist_Name=z['entityName']
#                 Dist_count=z['metric']['count']
#                 Dist_amount=z['metric']['amount']
#                 clm['State'].append(i)
#                 clm['Year'].append(j)
#                 clm['Quater'].append(int(k.strip('.json')))
#                 clm['District_Name'].append(Dist_Name)
#                 clm['DistrictWise_count'].append(Dist_count)
#                 clm['DistrictWise_amount'].append(Dist_amount)
#     Top_Trans_Dist_new = pd.DataFrame(clm)
#     Dist_name_list = ['south andaman', 'nicobars', 'north and middle andaman',
#                       'visakhapatnam', 'east godavari', 'krishna', 'chittoor', 'guntur',
#                       'kurnool', 'anantapur', 'west godavari', 'prakasam',
#                       'spsr nellore', 'ysr', 'papum pare', 'west kameng', 'lohit',
#                       'east siang', 'changlang', 'tawang', 'longding', 'west siang',
#                       'lower subansiri', 'namsai', 'lower siang', 'tirap',
#                       'lower dibang valley', 'kamrup metropolitan', 'marigaon',
#                       'barpeta', 'nagaon', 'cachar', 'sonitpur', 'kamrup', 'dibrugarh',
#                       'tinsukia', 'jorhat', 'dhubri', 'golaghat', 'goalpara', 'darrang',
#                       'bongaigaon', 'patna', 'muzaffarpur', 'purbi champaran', 'gaya',
#                       'samastipur', 'darbhanga', 'pashchim champaran', 'nalanda',
#                       'vaishali', 'rohtas', 'madhubani', 'bhagalpur', 'saran', 'siwan',
#                       'purnia', 'sitamarhi', 'chandigarh', 'raipur', 'durg',
#                       'janjgir champa', 'bilaspur', 'raigarh', 'korba', 'rajnandgaon',
#                       'surguja', 'mahasamund', 'baloda bazar', 'dadra and nagar haveli',
#                       'daman', 'diu', 'central delhi', 'new delhi', 'south east delhi',
#                       'west', 'north west', 'north', 'east', 'south', 'south west',
#                       'shahdara', 'north east', 'north goa', 'south goa', 'ahmadabad',
#                       'surat', 'vadodara', 'banas kantha', 'gandhinagar', 'mahesana',
#                       'rajkot', 'kachchh', 'bharuch', 'bhavnagar', 'valsad', 'navsari',
#                       'anand', 'gurugram', 'faridabad', 'hisar', 'rewari', 'panipat',
#                       'sonipat', 'karnal', 'sirsa', 'bhiwani', 'rohtak', 'ambala',
#                       'palwal', 'jhajjar', 'mewat', 'mahendragarh', 'solan', 'kangra',
#                       'shimla', 'mandi', 'chamba', 'una', 'sirmaur', 'hamirpur', 'kullu',
#                       'poonch', 'baramulla', 'jammu', 'anantnag', 'budgam', 'srinagar',
#                       'bandipore', 'pulwama', 'kulgam', 'ganderbal', 'udhampur',
#                       'kathua', 'kupwara', 'rajouri', 'samba', 'ramban', 'reasi',
#                       'ranchi', 'dhanbad', 'bokaro', 'east singhbhum', 'hazaribagh',
#                       'giridih', 'ramgarh', 'palamu', 'saraikela kharsawan', 'deoghar',
#                       'koderma', 'garhwa', 'bengaluru urban', 'mysuru', 'belagavi',
#                       'ballari', 'dharwad', 'bengaluru rural', 'dakshina kannada',
#                       'tumakuru', 'kalaburagi', 'bidar', 'kolar', 'ramanagara',
#                       'davanagere', 'shivamogga', 'hassan', 'vijayapura', 'ernakulam',
#                       'malappuram', 'kozhikode', 'thiruvananthapuram', 'thrissur',
#                       'palakkad', 'kottayam', 'kannur', 'kollam', 'alappuzha',
#                       'leh ladakh', 'kargil', 'lakshadweep', 'bhopal', 'indore',
#                       'gwalior', 'jabalpur', 'sehore', 'ujjain', 'sagar', 'rewa',
#                       'dewas', 'dhar', 'satna', 'narsinghpur', 'hoshangabad',
#                       'chhindwara', 'shahdol', 'pune', 'mumbai', 'mumbai suburban',
#                       'thane', 'nashik', 'aurangabad', 'nagpur', 'solapur', 'ahmednagar',
#                       'kolhapur', 'raigad', 'palghar', 'washim', 'imphal west',
#                       'imphal east', 'thoubal', 'bishnupur', 'kangpokpi',
#                       'churachandpur', 'kakching', 'ukhrul', 'jiribam', 'tamenglong',
#                       'tengnoupal', 'chandel', 'senapati', 'east khasi hills',
#                       'west garo hills', 'ribhoi', 'east jaintia hills',
#                       'west jaintia hills', 'west khasi hills', 'north garo hills',
#                       'south west garo hills', 'east garo hills', 'south garo hills',
#                       'aizawl', 'lunglei', 'kolasib', 'mamit', 'lawngtlai', 'serchhip',
#                       'saiha', 'champhai', 'dimapur', 'kohima', 'mokokchung', 'tuensang',
#                       'mon', 'zunheboto', 'wokha', 'phek', 'longleng', 'peren',
#                       'kiphire', 'khordha', 'cuttack', 'baleshwar', 'ganjam', 'jajapur',
#                       'bhadrak', 'puri', 'kendujhar', 'jagatsinghapur', 'mayurbhanj',
#                       'dhenkanal', 'nayagarh', 'anugul', 'sundargarh', 'sambalpur',
#                       'puducherry', 'karaikal', 'yanam', 'mahe', 'ludhiana', 'sas nagar',
#                       'patiala', 'jalandhar', 'fazilka', 'amritsar', 'bathinda',
#                       'sangrur', 'kapurthala', 'pathankot', 'hoshiarpur', 'gurdaspur',
#                       'jaipur', 'alwar', 'sikar', 'kota', 'jodhpur', 'bhilwara',
#                       'ganganagar', 'nagaur', 'ajmer', 'udaipur', 'dausa', 'jhunjhunu',
#                       'bikaner', 'barmer', 'chennai', 'chengalpattu', 'coimbatore',
#                       'thiruvallur', 'kancheepuram', 'tiruppur', 'salem', 'krishnagiri',
#                       'tiruchirappalli', 'madurai', 'vellore', 'erode', 'dharmapuri',
#                       'hyderabad', 'rangareddy', 'medchal malkajgiri', 'warangal urban',
#                       'sangareddy', 'karimnagar', 'nalgonda', 'khammam', 'peddapalle',
#                       'siddipet', 'bhadradri kothagudem', 'nirmal', 'nizamabad',
#                       'west tripura', 'south tripura', 'sepahijala', 'gomati',
#                       'north tripura', 'dhalai', 'khowai', 'unakoti',
#                       'gautam buddha nagar', 'lucknow', 'ghaziabad', 'prayagraj',
#                       'varanasi', 'kanpur nagar', 'gorakhpur', 'bareilly', 'agra',
#                       'meerut', 'sitapur', 'kheri', 'aligarh', 'moradabad', 'bijnor',
#                       'mathura', 'dehradun', 'udham singh nagar', 'haridwar', 'nainital',
#                       'pauri garhwal', 'tehri garhwal', 'almora', 'pithoragarh',
#                       'chamoli', 'uttarkashi', 'rudraprayag', 'birbhum', 'kolkata',
#                       'north twenty four parganas', 'murshidabad', 'nadia',
#                       'purba medinipur', 'maldah', 'south twenty four parganas',
#                       'paschim medinipur', 'purba bardhaman', 'bankura',
#                       'paschim bardhaman', 'purulia', 'hooghly', 'howrah']
#     dist_in_Title ={}
#     for i in Dist_name_list:
#         if i not in dist_in_Title:
#             dist_in_Title[i] = i.title()
#     Top_Trans_Dist_new['District_Name'] = Top_Trans_Dist_new['District_Name'].map(dist_in_Title)
#     my_dict = {'andaman-&-nicobar-islands':'Andaman & Nicobar Islands', 'andhra-pradesh':'Andhra Pradesh', 'arunachal-pradesh':'Arunachal Pradesh',
#                'assam':'Assam', 'bihar':'Bihar', 'chandigarh':'Chandigarh', 'chhattisgarh':'Chhattisgarh', 'dadra-&-nagar-haveli-&-daman-&-diu':'Dadra & Nagar Haveli & Daman & Diu',
#                'delhi':'Delhi', 'goa':'Goa', 'gujarat':'Gujarat', 'haryana':'Haryana', 'himachal-pradesh':'Himachal Pradesh', 'jammu-&-kashmir':'Jammu & Kashmir',
#                'jharkhand':'Jharkhand', 'karnataka':'Karnataka', 'kerala':'Kerala', 'ladakh':'Ladakh', 'lakshadweep':'Lakshadweep', 'madhya-pradesh':'Madhya Pradesh',
#                'maharashtra':'Maharashtra', 'manipur':'Manipur', 'meghalaya':'Meghalaya', 'mizoram':'Mizoram', 'nagaland':'Nagaland', 'odisha':'Odisha',
#                'puducherry':'Puducherry', 'punjab':'Punjab', 'rajasthan':'Rajasthan', 'sikkim':'Sikkim', 'tamil-nadu':'Tamil Nadu', 'telangana':'Telengana',
#                'tripura':'Tripura', 'uttar-pradesh':'Uttar Pradesh', 'uttarakhand':'Uttarakhand', 'west-bengal':'West Bengal'}
#     Top_Trans_Dist_new['State'] = Top_Trans_Dist_new['State'].map(my_dict)
#     return Top_Trans_Dist_new
#
#
# def Top_User_Dist_new(m):
#     path = r'Desktop/Project/Phonepe db/data/top/user/country/india/state'
#     Top_state_list_new=os.listdir(path)
#     clm={'State':[], 'Year':[],'Quater':[],'District_Name':[], 'Registred_Users_count':[]}
#     for i in Top_state_list_new:
#         p_i=path+'/'+i
#         Top_yr_list_new=os.listdir(p_i)
#         j = Top_yr_list_new[-1]
#         p_j=p_i+'/'+ j
#         Top_yr_jlist_new=os.listdir(p_j)
#         for a in range (-1,-(m+1),-1):
#             k = Top_yr_jlist_new[a]
#             p_k=p_j+'/'+k
#             Data=open(p_k,'r')
#             D=json.load(Data)
#             for z in D['data']['districts']:
#                 Dist_Name=z['name']
#                 RegUser_count=z['registeredUsers']
#                 clm['State'].append(i)
#                 clm['Year'].append(j)
#                 clm['Quater'].append(int(k.strip('.json')))
#                 clm['District_Name'].append(Dist_Name)
#                 clm['Registred_Users_count'].append(RegUser_count)
#     Top_User_Dist_new = pd.DataFrame(clm)
#     Dist_name_list = ['south andaman', 'nicobars', 'north and middle andaman',
#                       'visakhapatnam', 'east godavari', 'krishna', 'chittoor', 'guntur',
#                       'kurnool', 'anantapur', 'west godavari', 'prakasam',
#                       'spsr nellore', 'ysr', 'papum pare', 'west kameng', 'lohit',
#                       'east siang', 'changlang', 'tawang', 'longding', 'west siang',
#                       'lower subansiri', 'namsai', 'lower siang', 'tirap',
#                       'lower dibang valley', 'kamrup metropolitan', 'marigaon',
#                       'barpeta', 'nagaon', 'cachar', 'sonitpur', 'kamrup', 'dibrugarh',
#                       'tinsukia', 'jorhat', 'dhubri', 'golaghat', 'goalpara', 'darrang',
#                       'bongaigaon', 'patna', 'muzaffarpur', 'purbi champaran', 'gaya',
#                       'samastipur', 'darbhanga', 'pashchim champaran', 'nalanda',
#                       'vaishali', 'rohtas', 'madhubani', 'bhagalpur', 'saran', 'siwan',
#                       'purnia', 'sitamarhi', 'chandigarh', 'raipur', 'durg',
#                       'janjgir champa', 'bilaspur', 'raigarh', 'korba', 'rajnandgaon',
#                       'surguja', 'mahasamund', 'baloda bazar', 'dadra and nagar haveli',
#                       'daman', 'diu', 'central delhi', 'new delhi', 'south east delhi',
#                       'west', 'north west', 'north', 'east', 'south', 'south west',
#                       'shahdara', 'north east', 'north goa', 'south goa', 'ahmadabad',
#                       'surat', 'vadodara', 'banas kantha', 'gandhinagar', 'mahesana',
#                       'rajkot', 'kachchh', 'bharuch', 'bhavnagar', 'valsad', 'navsari',
#                       'anand', 'gurugram', 'faridabad', 'hisar', 'rewari', 'panipat',
#                       'sonipat', 'karnal', 'sirsa', 'bhiwani', 'rohtak', 'ambala',
#                       'palwal', 'jhajjar', 'mewat', 'mahendragarh', 'solan', 'kangra',
#                       'shimla', 'mandi', 'chamba', 'una', 'sirmaur', 'hamirpur', 'kullu',
#                       'poonch', 'baramulla', 'jammu', 'anantnag', 'budgam', 'srinagar',
#                       'bandipore', 'pulwama', 'kulgam', 'ganderbal', 'udhampur',
#                       'kathua', 'kupwara', 'rajouri', 'samba', 'ramban', 'reasi',
#                       'ranchi', 'dhanbad', 'bokaro', 'east singhbhum', 'hazaribagh',
#                       'giridih', 'ramgarh', 'palamu', 'saraikela kharsawan', 'deoghar',
#                       'koderma', 'garhwa', 'bengaluru urban', 'mysuru', 'belagavi',
#                       'ballari', 'dharwad', 'bengaluru rural', 'dakshina kannada',
#                       'tumakuru', 'kalaburagi', 'bidar', 'kolar', 'ramanagara',
#                       'davanagere', 'shivamogga', 'hassan', 'vijayapura', 'ernakulam',
#                       'malappuram', 'kozhikode', 'thiruvananthapuram', 'thrissur',
#                       'palakkad', 'kottayam', 'kannur', 'kollam', 'alappuzha',
#                       'leh ladakh', 'kargil', 'lakshadweep', 'bhopal', 'indore',
#                       'gwalior', 'jabalpur', 'sehore', 'ujjain', 'sagar', 'rewa',
#                       'dewas', 'dhar', 'satna', 'narsinghpur', 'hoshangabad',
#                       'chhindwara', 'shahdol', 'pune', 'mumbai', 'mumbai suburban',
#                       'thane', 'nashik', 'aurangabad', 'nagpur', 'solapur', 'ahmednagar',
#                       'kolhapur', 'raigad', 'palghar', 'washim', 'imphal west',
#                       'imphal east', 'thoubal', 'bishnupur', 'kangpokpi',
#                       'churachandpur', 'kakching', 'ukhrul', 'jiribam', 'tamenglong',
#                       'tengnoupal', 'chandel', 'senapati', 'east khasi hills',
#                       'west garo hills', 'ribhoi', 'east jaintia hills',
#                       'west jaintia hills', 'west khasi hills', 'north garo hills',
#                       'south west garo hills', 'east garo hills', 'south garo hills',
#                       'aizawl', 'lunglei', 'kolasib', 'mamit', 'lawngtlai', 'serchhip',
#                       'saiha', 'champhai', 'dimapur', 'kohima', 'mokokchung', 'tuensang',
#                       'mon', 'zunheboto', 'wokha', 'phek', 'longleng', 'peren',
#                       'kiphire', 'khordha', 'cuttack', 'baleshwar', 'ganjam', 'jajapur',
#                       'bhadrak', 'puri', 'kendujhar', 'jagatsinghapur', 'mayurbhanj',
#                       'dhenkanal', 'nayagarh', 'anugul', 'sundargarh', 'sambalpur',
#                       'puducherry', 'karaikal', 'yanam', 'mahe', 'ludhiana', 'sas nagar',
#                       'patiala', 'jalandhar', 'fazilka', 'amritsar', 'bathinda',
#                       'sangrur', 'kapurthala', 'pathankot', 'hoshiarpur', 'gurdaspur',
#                       'jaipur', 'alwar', 'sikar', 'kota', 'jodhpur', 'bhilwara',
#                       'ganganagar', 'nagaur', 'ajmer', 'udaipur', 'dausa', 'jhunjhunu',
#                       'bikaner', 'barmer', 'chennai', 'chengalpattu', 'coimbatore',
#                       'thiruvallur', 'kancheepuram', 'tiruppur', 'salem', 'krishnagiri',
#                       'tiruchirappalli', 'madurai', 'vellore', 'erode', 'dharmapuri',
#                       'hyderabad', 'rangareddy', 'medchal malkajgiri', 'warangal urban',
#                       'sangareddy', 'karimnagar', 'nalgonda', 'khammam', 'peddapalle',
#                       'siddipet', 'bhadradri kothagudem', 'nirmal', 'nizamabad',
#                       'west tripura', 'south tripura', 'sepahijala', 'gomati',
#                       'north tripura', 'dhalai', 'khowai', 'unakoti',
#                       'gautam buddha nagar', 'lucknow', 'ghaziabad', 'prayagraj',
#                       'varanasi', 'kanpur nagar', 'gorakhpur', 'bareilly', 'agra',
#                       'meerut', 'sitapur', 'kheri', 'aligarh', 'moradabad', 'bijnor',
#                       'mathura', 'dehradun', 'udham singh nagar', 'haridwar', 'nainital',
#                       'pauri garhwal', 'tehri garhwal', 'almora', 'pithoragarh',
#                       'chamoli', 'uttarkashi', 'rudraprayag', 'birbhum', 'kolkata',
#                       'north twenty four parganas', 'murshidabad', 'nadia',
#                       'purba medinipur', 'maldah', 'south twenty four parganas',
#                       'paschim medinipur', 'purba bardhaman', 'bankura',
#                       'paschim bardhaman', 'purulia', 'hooghly', 'howrah']
#     dist_in_Title ={}
#     for i in my_dist_list:
#         if i not in dist_in_Title:
#             dist_in_Title[i] = i.title()
#     Top_User_Dist_new['District_Name'] = Top_User_Dist_new['District_Name'].map(dist_in_Title)
#     my_dict = {'andaman-&-nicobar-islands':'Andaman & Nicobar Islands', 'andhra-pradesh':'Andhra Pradesh', 'arunachal-pradesh':'Arunachal Pradesh',
#                'assam':'Assam', 'bihar':'Bihar', 'chandigarh':'Chandigarh', 'chhattisgarh':'Chhattisgarh', 'dadra-&-nagar-haveli-&-daman-&-diu':'Dadra & Nagar Haveli & Daman & Diu',
#                'delhi':'Delhi', 'goa':'Goa', 'gujarat':'Gujarat', 'haryana':'Haryana', 'himachal-pradesh':'Himachal Pradesh', 'jammu-&-kashmir':'Jammu & Kashmir',
#                'jharkhand':'Jharkhand', 'karnataka':'Karnataka', 'kerala':'Kerala', 'ladakh':'Ladakh', 'lakshadweep':'Lakshadweep', 'madhya-pradesh':'Madhya Pradesh',
#                'maharashtra':'Maharashtra', 'manipur':'Manipur', 'meghalaya':'Meghalaya', 'mizoram':'Mizoram', 'nagaland':'Nagaland', 'odisha':'Odisha',
#                'puducherry':'Puducherry', 'punjab':'Punjab', 'rajasthan':'Rajasthan', 'sikkim':'Sikkim', 'tamil-nadu':'Tamil Nadu', 'telangana':'Telengana',
#                'tripura':'Tripura', 'uttar-pradesh':'Uttar Pradesh', 'uttarakhand':'Uttarakhand', 'west-bengal':'West Bengal'}
#     Top_User_Dist_new['State'] = Top_User_Dist_new['State'].map(my_dict)
#     return Top_User_Dist_new
#
#
# def Top_User_Pcodes_new(m):
#     path = r'Desktop/Project/Phonepe db/data/top/user/country/india/state'
#     Top_state_list_new=os.listdir(path)
#     clm={'State':[], 'Year':[],'Quater':[],'Pincodes':[], 'Registred_Users_count':[]}
#     for i in Top_state_list_new:
#         p_i=path+'/'+i
#         Top_yr_list_new=os.listdir(p_i)
#         j = Top_yr_list_new[-1]
#         p_j=p_i+'/'+ j
#         Top_yr_jlist_new=os.listdir(p_j)
#         for a in range (-1,-(m+1),-1):
#             k = Top_yr_jlist_new[a]
#             p_k=p_j+'/'+k
#             Data=open(p_k,'r')
#             D=json.load(Data)
#             for z in D['data']['pincodes']:
#                 Pin = z['name']
#                 RegUser_count = z['registeredUsers']
#                 clm['State'].append(i)
#                 clm['Year'].append(j)
#                 clm['Quater'].append(int(k.strip('.json')))
#                 clm['Pincodes'].append(Pin)
#                 clm['Registred_Users_count'].append(RegUser_count)
#     Top_User_Pcodes_new = pd.DataFrame(clm)
#     my_dict = {'andaman-&-nicobar-islands':'Andaman & Nicobar Islands', 'andhra-pradesh':'Andhra Pradesh', 'arunachal-pradesh':'Arunachal Pradesh',
#                'assam':'Assam', 'bihar':'Bihar', 'chandigarh':'Chandigarh', 'chhattisgarh':'Chhattisgarh', 'dadra-&-nagar-haveli-&-daman-&-diu':'Dadra & Nagar Haveli & Daman & Diu',
#                'delhi':'Delhi', 'goa':'Goa', 'gujarat':'Gujarat', 'haryana':'Haryana', 'himachal-pradesh':'Himachal Pradesh', 'jammu-&-kashmir':'Jammu & Kashmir',
#                'jharkhand':'Jharkhand', 'karnataka':'Karnataka', 'kerala':'Kerala', 'ladakh':'Ladakh', 'lakshadweep':'Lakshadweep', 'madhya-pradesh':'Madhya Pradesh',
#                'maharashtra':'Maharashtra', 'manipur':'Manipur', 'meghalaya':'Meghalaya', 'mizoram':'Mizoram', 'nagaland':'Nagaland', 'odisha':'Odisha',
#                'puducherry':'Puducherry', 'punjab':'Punjab', 'rajasthan':'Rajasthan', 'sikkim':'Sikkim', 'tamil-nadu':'Tamil Nadu', 'telangana':'Telengana',
#                'tripura':'Tripura', 'uttar-pradesh':'Uttar Pradesh', 'uttarakhand':'Uttarakhand', 'west-bengal':'West Bengal'}
#     Top_User_Pcodes_new['State'] = Top_User_Pcodes_new['State'].map(my_dict)
#     return Top_User_Pcodes_new
#
# def Top_Trans_Pcodes_new(m):
#     path = r'Desktop/Project/Phonepe db/data/top/transaction/country/india/state'
#     Top_state_list_new=os.listdir(path)
#     clm={'State':[], 'Year':[],'Quater':[], 'Pincodes':[], 'PincodeWise_count':[], 'PincodeWise_amount':[]}
#     for i in Top_state_list:
#         p_i=path+'/'+i
#         Top_yr_list_new=os.listdir(p_i)
#         j = Top_yr_list_new[-1]
#         p_j=p_i+'/'+ j
#         Top_yr_jlist_new=os.listdir(p_j)
#         for a in range (-1,-(m+1),-1):
#             k = Top_yr_list[a]
#             p_k=p_j+'/'+k
#             Data=open(p_k,'r')
#             D=json.load(Data)
#             for y in D['data']['pincodes']:
#                 Pin = y['entityName']
#                 Pin_count=z['metric']['count']
#                 Pin_amount=z['metric']['amount']
#                 clm['State'].append(i)
#                 clm['Year'].append(j)
#                 clm['Quater'].append(int(k.strip('.json')))
#                 clm['Pincodes'].append(Pin)
#                 clm['PincodeWise_count'].append(Pin_count)
#                 clm['PincodeWise_amount'].append(Pin_amount)
#     Top_Trans_Pcodes_new = pd.DataFrame(clm)
#     my_dict = {'andaman-&-nicobar-islands':'Andaman & Nicobar Islands', 'andhra-pradesh':'Andhra Pradesh', 'arunachal-pradesh':'Arunachal Pradesh',
#                'assam':'Assam', 'bihar':'Bihar', 'chandigarh':'Chandigarh', 'chhattisgarh':'Chhattisgarh', 'dadra-&-nagar-haveli-&-daman-&-diu':'Dadra & Nagar Haveli & Daman & Diu',
#                'delhi':'Delhi', 'goa':'Goa', 'gujarat':'Gujarat', 'haryana':'Haryana', 'himachal-pradesh':'Himachal Pradesh', 'jammu-&-kashmir':'Jammu & Kashmir',
#                'jharkhand':'Jharkhand', 'karnataka':'Karnataka', 'kerala':'Kerala', 'ladakh':'Ladakh', 'lakshadweep':'Lakshadweep', 'madhya-pradesh':'Madhya Pradesh',
#                'maharashtra':'Maharashtra', 'manipur':'Manipur', 'meghalaya':'Meghalaya', 'mizoram':'Mizoram', 'nagaland':'Nagaland', 'odisha':'Odisha',
#                'puducherry':'Puducherry', 'punjab':'Punjab', 'rajasthan':'Rajasthan', 'sikkim':'Sikkim', 'tamil-nadu':'Tamil Nadu', 'telangana':'Telengana',
#                'tripura':'Tripura', 'uttar-pradesh':'Uttar Pradesh', 'uttarakhand':'Uttarakhand', 'west-bengal':'West Bengal'}
#     Top_Trans_Pcodes_new['State'] = Top_Trans_Pcodes_new['State'].map(my_dict)
#     return Top_Trans_Pcodes_new

# %% [raw]
# # code to update database by 1 or more than 1 quater data once every 5 months
#
# l, m = PhonePe()  # PhonePe returns the len(Agg_yr_list), len(Agg_yr_jlist)
#
# counter = 0
# while True:
#     if counter>4:
#         break
#     counter+=1
#     repository_url = 'https://github.com/PhonePe/pulse.git'
#     destination_directory = "Desktop/Project/PhonePe/data_new"
#     git.Repo.clone_from(repository_url, destination_directory)
#     path_new = r'Desktop/Project/Phonepe db/data_new/aggregated/transaction/country/india/state'
#     Agg_state_list_new=os.listdir(path_new)
#     clm={'State':[], 'Year':[],'Quater':[],'Transacion_type':[], 'Transacion_count':[], 'Transacion_amount':[]}
#     for i in Agg_state_list_new:
#         p_i=path+'/'+i
#         Agg_yr__list_new=os.listdir(p_i)
#         if len( Agg_yr_list_new) >= len(Agg_yr_list):
#             j = Agg_yr_list_new[-1]
#             p_j=p_i+'/'+ j
#             Agg_yr_jlist_new=os.listdir(p_j)
#             if len(Agg_yr_jlist_new) > len(Agg_yr_jlist):
#                 x = True
#                 for a in range (-1,-(m+1),-1):
#                     k = Agg_yr_jlist_new[a]
#                     p_k=p_j+'/'+k
#                     Data=open(p_k,'r')
#                     D=json.load(Data)
#                     for z in D['data']['transactionData']:
#                         Name=z['name']
#                         count=z['paymentInstruments'][0]['count']
#                         amount=z['paymentInstruments'][0]['amount']
#                         clm['Transacion_type'].append(Name)
#                         clm['Transacion_count'].append(count)
#                         clm['Transacion_amount'].append(amount)
#                         clm['State'].append(i)
#                         clm['Year'].append(j)
#                         clm['Quater'].append(int(k.strip('.json')))
#             else:
#                 break
#     Agg_Trans_new=pd.DataFrame(clm)
#
#     my_dict = {'andaman-&-nicobar-islands':'Andaman & Nicobar Islands', 'andhra-pradesh':'Andhra Pradesh', 'arunachal-pradesh':'Arunachal Pradesh',
#                'assam':'Assam', 'bihar':'Bihar', 'chandigarh':'Chandigarh', 'chhattisgarh':'Chhattisgarh', 'dadra-&-nagar-haveli-&-daman-&-diu':'Dadra & Nagar Haveli & Daman & Diu',
#                'delhi':'Delhi', 'goa':'Goa', 'gujarat':'Gujarat', 'haryana':'Haryana', 'himachal-pradesh':'Himachal Pradesh', 'jammu-&-kashmir':'Jammu & Kashmir',
#                'jharkhand':'Jharkhand', 'karnataka':'Karnataka', 'kerala':'Kerala', 'ladakh':'Ladakh', 'lakshadweep':'Lakshadweep', 'madhya-pradesh':'Madhya Pradesh',
#                'maharashtra':'Maharashtra', 'manipur':'Manipur', 'meghalaya':'Meghalaya', 'mizoram':'Mizoram', 'nagaland':'Nagaland', 'odisha':'Odisha',
#                'puducherry':'Puducherry', 'punjab':'Punjab', 'rajasthan':'Rajasthan', 'sikkim':'Sikkim', 'tamil-nadu':'Tamil Nadu', 'telangana':'Telengana',
#                'tripura':'Tripura', 'uttar-pradesh':'Uttar Pradesh', 'uttarakhand':'Uttarakhand', 'west-bengal':'West Bengal'}
#
#     Agg_Trans_new['State'] = Agg_Trans_new['State'].map(my_dict)
#
#     Agg_Trans_new.rename(columns={'Quater':'Quarter','Transacion_type':'Transaction_Type','Transacion_count':'Transaction_Count','Transacion_amount':'Transaction_Amount'},inplace=True)
#
#     insert_query = 'INSERT INTO Agg_Trans (State,Year,Quarter,Transaction_Type,Transaction_Count,Transaction_Amount) VALUES (%s,%s,%s,%s,%s,%s)'
#     values = [(row["State"], row["Year"], row["Quarter"],row["Transaction_Type"],row["Transaction_Count"],row["Transaction_Amount"]) for _, row in Agg_Trans_new.iterrows()]
#     pointer.executemany(insert_query, values)
#
#     if x == True:
#         Agg_Userf_new = Agg_Userf(m)
#         insert_query = 'INSERT INTO Agg_Userf (State,Year,Quarter,UserByDevice_Brand,UserByDevice_Count,UserByDevice_Percentage) VALUES (%s,%s,%s,%s,%s,%s)'
#         values = [(row["State"], row["Year"], row["Quarter"],row["UserByDevice_Brand"],row["UserByDevice_Count"],row["UserByDevice_Percentage"]) for _, row in Agg_Userf_new.iterrows()]
#         pointer.executemany(insert_query, values)
#
#         Map_Transf_new = Map_Transf(m)
#         insert_query = 'INSERT INTO Map_Transf (State,Year,Quarter,District_Name,Districtwise_TransactionCount,Districtwise_TransactionAmount) VALUES (%s,%s,%s,%s,%s,%s)'
#         values = [(row["State"], row["Year"], row["Quater"],row["District_Name"],row["DistrictWise_T.count"],row["DistrictWise_T.amount"]) for _, row in Map_Transf_new.iterrows()]
#         pointer.executemany(insert_query, values)
#
#         Map_Users_new = Map_Users(m)
#         insert_query = 'INSERT INTO Map_Users (State,Year,Quarter,District_Name,Registered_Users_Count,AppOpens) VALUES (%s,%s,%s,%s,%s,%s)'
#         values = [(row["State"], row["Year"], row["Quater"],row["District_Name"],row["Registered_Users_Count"],row["AppOpens"]) for _, row in Map_Users_new.iterrows()]
#         pointer.executemany(insert_query, values)
#
#         Top_Trans_Dist_new = Top_Trans_Dist(m)
#         insert_query = 'INSERT INTO Top_Trans_Dist (State,Year,Quarter,District_Name,Districtwise_TransactionCount,Districtwise_TransactionAmount) VALUES (%s,%s,%s,%s,%s,%s)'
#         values = [(row["State"], row["Year"], row["Quater"],row["District_Name"],row["DistrictWise_count"],row["DistrictWise_amount"]) for _, row in Top_Trans_Dist_new.iterrows()]
#         pointer.executemany(insert_query, values)
#
#         Top_User_Dist_new = Top_User_Dist(m)
#         insert_query = 'INSERT INTO Top_User_Dist (State,Year,Quarter,District_Name,Registred_Users_count) VALUES (%s,%s,%s,%s,%s)'
#         values = [(row["State"], row["Year"], row["Quater"],row["District_Name"],row["Registred_Users_count"]) for _, row in Top_User_Dist_new.iterrows()]
#         pointer.executemany(insert_query, values)
#
#         Top_User_Pcodes_new = Top_User_Pcodes(m)
#         insert_query = 'INSERT INTO Top_User_Pcodes (State,Year,Quarter,Pincodes,Registred_Users_count) VALUES (%s,%s,%s,%s,%s)'
#         values = [(row["State"], row["Year"], row["Quater"],row["Pincodes"],row["Registred_Users_count"]) for _, row in Top_User_Pcodes_new.iterrows()]
#         pointer.executemany(insert_query, values)
#
#         Top_Trans_Pcodes_new = Top_User_Pcodes(m)
#         insert_query = 'INSERT INTO Top_Trans_Pcodes (State,Year,Quarter,Pincodes,Pincodewise_TransactionCount,Pincodewise_TransactionAmount) VALUES (%s,%s,%s,%s,%s,%s)'
#         values = [(row["State"], row["Year"], row["Quater"],row["Pincodes"],row["PincodeWise_count"],row["PincodeWise_amount"]) for _, row in Top_Trans_Pcodes_new.iterrows()]
#         pointer.executemany(insert_query, values)
#
#
#     mydb.commmit()
#     pointer.close()
#     mydb.close()
#     time.sleep(12960000)
